# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
# %matplotlib inline

import os

# %%
pwd
# Out:
# 'C:\\Users\\User\\Desktop\\PROJECT WORK\\Jupyter Repo'

# %%
df = pd.read_csv("Bengaluru_CSV/Bengaluru_House_Data.csv")

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.shape
# Out:
# (13320, 9)

# %%
missingno.matrix(df)

# %%
round(df["society"].isna().sum()*100/len(df),2)
# Out:
# 41.31

# %%
df1 = df.drop(["society"], axis=1)

# %%
df1.isna().sum()
# Out:
# area_type         0
# availability      0
# location          1
# size             16
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %% [markdown]
# # df1["balcony"].value_counts()

# %%
sns.distplot(df1["balcony"], kde=False, bins=4)

# %%
df1["balcony"].median()
# Out:
# 2.0

# %%
df1["balcony"].mean()
# Out:
# 1.5843757375501535
