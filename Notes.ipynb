# %% [markdown]
# https://medium.com/dunder-data/selecting-subsets-of-data-in-pandas-39e811c81a0c
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html
#
# Remember then when you filter by a series
#     series_of_females = test_one["Sex"]=="female"
# It returns a series of boolean. So if you pass it into a df, it returns rows with 1
# If you pass it into another series, it also returns rows with 1.

# %% [markdown]
# # Choosing Model
# ![image.png](attachment:image.png)

# %% [markdown]
# # Pandas Cheatsheet
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Confusion matrix can be used to visually show where and how the model predicted wrongly
#
# https://www.youtube.com/watch?v=J5bXOOmkopc&list=PLeo1K3hjS3uvCeTYTeyfe0-rN5r8zn9rw&index=9&ab_channel=codebasics

# %%
start = input()
num = int(start)
if num > 1:
    i = 2
    while num != 1: 
        if num/i == int(num/i):
            print(i)
            num = num/i
        else:
            i += 1
else: 
    print(num)
# Out:
# 20
# 2
# 2
# 5

# %% [markdown]
# https://www.kaggle.com/discdiver/guide-to-scaling-and-standardizing
# https://www.kaggle.com/zlatankr/titanic-random-forest-82-78
